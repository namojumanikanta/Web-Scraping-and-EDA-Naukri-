# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading CSV File

# %%
df1=pd.read_csv(r"C:\Users\Namoju Manikanta\OneDrive\Documents\webscrappin naukri\final_data_frame14.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             401 non-null    int64
#  1   Job_role               353 non-null    object
#  2   Company                400 non-null    object
#  3   Min_Experience(years)  401 non-null    int64
#  4   Max_Experience(years)  401 non-null    int64
#  5   Location               401 non-null    object
#  6   Skills                 401 non-null    object
#  7   Rating                 401 non-null    float64
#  8   min_salary(PA)         401 non-null    object
#  9   max_salary(PA)         401 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 31.5+ KB

# %%
df1['Job_role'].fillna(method = 'ffill', inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             401 non-null    int64
#  1   Job_role               401 non-null    object
#  2   Company                400 non-null    object
#  3   Min_Experience(years)  401 non-null    int64
#  4   Max_Experience(years)  401 non-null    int64
#  5   Location               401 non-null    object
#  6   Skills                 401 non-null    object
#  7   Rating                 401 non-null    float64
#  8   min_salary(PA)         401 non-null    object
#  9   max_salary(PA)         401 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 31.5+ KB

# %%
df1['Company'].fillna(method = 'ffill', inplace = True)

# %%
df1[['max_salary(PA)','max','space']] = df1['max_salary(PA)'].str.split(' ', expand = True)

# %%
df1.drop(['max_salary(PA)','space','Unnamed: 0'], inplace = True, axis = 1)

# %%
df1
# Out:
#               Job_role                      Company  Min_Experience(years)  \
# 0    Software Engineer                         Ugam                      3
# 1    Software Engineer                     Useready                      3
# 2    Software Engineer                     Infinite                      3
# 3    Software Engineer                  GlobalLogic                      0
# 4    Software Engineer    Avya Technology Pvt. Ltd.                      6
# ..                 ...                          ...                    ...
# 396      Sales Manager                    Info Edge                      2
# 397      Sales Manager                     Watertec                      3
# 398      Sales Manager  JM Financial Home Loans Ltd                      3
# 399      Sales Manager                 JRK Research                      0
# 400      Sales Manager         Kotak Life Insurance                      5
#
# ...

# %%
df1.rename(columns = {'max':'max_salary(PA)'}, inplace = True)

# %%
df1
# Out:
#               Job_role                      Company  Min_Experience(years)  \
# 0    Software Engineer                         Ugam                      3
# 1    Software Engineer                     Useready                      3
# 2    Software Engineer                     Infinite                      3
# 3    Software Engineer                  GlobalLogic                      0
# 4    Software Engineer    Avya Technology Pvt. Ltd.                      6
# ..                 ...                          ...                    ...
# 396      Sales Manager                    Info Edge                      2
# 397      Sales Manager                     Watertec                      3
# 398      Sales Manager  JM Financial Home Loans Ltd                      3
# 399      Sales Manager                 JRK Research                      0
# 400      Sales Manager         Kotak Life Insurance                      5
#
# ...

# %%
df1['max_salary(PA)'][0].replace(",","")
# Out:
# '1400000'

# %%
a = list(map(lambda x:x.replace(",",""),df1['max_salary(PA)']))

# %%
df1['max_salary(PA)'] = a

# %%
df1['min_salary(PA)'][0].replace(",","")
# Out:
# '500000'

# %%
b = list(map(lambda x:x.replace(",",""),df1['min_salary(PA)']))

# %%
df1['min_salary(PA)'] = b

# %%
df2 = pd.read_csv(r"C:\Users\Namoju Manikanta\OneDrive\Documents\webscrappin naukri\final_data_frame15.csv")

# %%
df2['min_salary(PA)'] = df2['min_salary(PA)'].astype(int)

# %%
df2['max_salary(PA)'] = df2['max_salary(PA)'].astype(int)

# %%
df2['Rating'][298]
# Out:
# 4.0

# %% [markdown]
# ## Visualization

# %% [markdown]
# # Univariant Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2["Job_role"].value_counts()
# Out:
# Software Developer    130
# Data Engineer          95
# Data Analyst           76
# Software Engineer      44
# System Engineer        32
# Sales Manager          22
# Stack Developer         2
# Name: Job_role, dtype: int64

# %%
a=df2["Job_role"].value_counts()
a
# Out:
# Software Developer    130
# Data Engineer          95
# Data Analyst           76
# Software Engineer      44
# System Engineer        32
# Sales Manager          22
# Stack Developer         2
# Name: Job_role, dtype: int64

# %%
plt.figure(figsize=(10,6))
df2['Job_role'].value_counts().plot.bar();
plt.title("Number of Jobs for specific role")
plt.show()

# %% [markdown]
# * From the above plot software developer has high number of jobs
# * Stack Developer and Sales Manager has low jobs

# %%
plt.figure(figsize=(17,10))
x=pd.DataFrame(df2["Job_role"].value_counts())
explode=[0.1,0.1,0.1,0.1,0.2,0.2,0.2]
plt.pie(df2["Job_role"].value_counts(),labels=x.index,explode=explode,autopct="%1.2f%%",shadow=True)
plt.title("Types Of Jobrole",fontsize=(15))
plt.legend(bbox_to_anchor=(1.1,1))
plt.show()

# %% [markdown]
# * From above Pie chart we can know that Software Developer and Data Engineer have high perecntage of jobs

# %%
df2['Location'].value_counts()
# Out:
# Bangalore/Bengaluru                                           56
# Hyderabad/Secunderabad                                        28
# Permanent Remote                                              20
# Hybrid - Bangalore/Bengaluru                                  19
# Gurgaon/Gurugram                                              16
#                                                               ..
# Bangalore/Bengaluru(Electronic City)                           1
# Hybrid - Chandigarh, Gurgaon/Gurugram, Bangalore/Bengaluru     1
# Chennai, Bangalore/Bengaluru                                   1
# Temp. WFH - PAN India                                          1
# Mumbai, Mumbai Suburban, Thane                                 1
# Name: Location, Length: 160, dtype: int64

# %%
plt.figure(figsize=(10,6))
df2['Location'].value_counts()[:20].plot(kind='barh')
plt.title("Num of jobs at particular Location")
# Out:
# Text(0.5, 1.0, 'Num of jobs at particular Location')

# %% [markdown]
# * most number of jobroles are from Bangalore, Hyderabad and gurgaon
# * Delhi has less number of jobs

# %%
plt.figure(figsize=(10,6))
df2['Company'].value_counts()[:20].plot(kind='barh')
plt.title("Num of vacancies in a company ")
# Out:
# Text(0.5, 1.0, 'Num of vacancies in a company ')

# %%
plt.figure(figsize=(10,6))
df2['Min_Experience(years)'].plot( kind = 'density');
plt.title("Showing density of Min_Experience(years) ")
plt.show()

# %%
plt.figure(figsize=(10,6))
df2['Max_Experience(years)'].plot( kind = 'density');
plt.title("Showing density of Min_Experience(years) ")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df2['max_salary(PA)'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * most jobs are with salary package of 3,50,000 - 4,00,000

# %% [markdown]
# # Bivariant Analysis

# %%
plt.figure(figsize=(10,6))
df2[df2['max_salary(PA)'] < 400000].plot.scatter(x='max_salary(PA)', y='Job_role')
plt.title("Showing job_roles with a max_salary(pA) less than 400000")
# Out:
# Text(0.5, 1.0, 'Showing job_roles with a max_salary(pA) less than 400000')

# %% [markdown]
# * Jobroles with maximum salary package less than 4,00,000 and most of the jobs lies between 3,00,000 and 4,00,000

# %%
plt.figure(figsize=(10,6))
df2[df2['min_salary(PA)'] < 400000].plot.scatter(x='min_salary(PA)', y='Job_role')
plt.title("Showing job_roles with a min_salary(pA) less than 400000")
# Out:
# Text(0.5, 1.0, 'Showing job_roles with a min_salary(pA) less than 400000')

# %% [markdown]
#  * Jobroles with mainimum salary package less than 4,00,000 and software developer has more jobs

# %%
plt.figure(figsize=(10,6))
df2.plot(x = 'Max_Experience(years)', y = 'max_salary(PA)', kind = 'scatter');
plt.title('Max_Experience Vs max_salary(PA)')
plt.show()

# %%
plt.figure(figsize=(10,5))
df2.boxplot('max_salary(PA)');
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.catplot(data = a, x = 'Rating', y = 'max_salary(PA)', 
            color = 'blue', kind = 'box');
plt.show()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             401 non-null    int64
#  1   Job_role               401 non-null    object
#  2   Company                401 non-null    object
#  3   Min_Experience(years)  401 non-null    int64
#  4   Max_Experience(years)  401 non-null    int64
#  5   Location               401 non-null    object
#  6   Skills                 401 non-null    object
#  7   Rating                 401 non-null    float64
#  8   min_salary(PA)         401 non-null    int32
#  9   max_salary(PA)         401 non-null    int32
# dtypes: float64(1), int32(2), int64(3), object(4)
# memory usage: 28.3+ KB

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = df2, x = 'max_salary(PA)', y = 'Job_role');
plt.title('Showing Job_roles having highest salary Package ')
plt.show()

# %% [markdown]
# * The Data Analyst has the highest Salary package

# %%
plt.figure(figsize=(17,20))
sns.catplot(data=df2, x="Min_Experience(years)", y="Job_role", kind="box")
plt.title('job_roles with min_experience')
# Out:
# Text(0.5, 1.0, 'job_roles with min_experience')

# %% [markdown]
# * The System Engineer, Software Engineer, Data Analyst, Software Developer and Stack Developers need the minimum experience of 2.5 to 3 years approximately.
# * The Data Engineer,Sales Manager needs the minimun experience of 4 years approximately.

# %%
df2[(df2['Rating']<3)]['Company'].value_counts().plot(kind='barh')
plt.title('Showing companies having rating less than 3')
# Out:
# Text(0.5, 1.0, 'Showing companies having rating less than 3')

# %% [markdown]
# * Companies which are having less than 3 Rating

# %%
#df2[(df2['Rating']>4.5)]['Company'].value_counts().plot(kind='barh')
#plt.title('Showing companies having rating greater than 4.5')

# %%
plt.figure(figsize=(10,5))
df2.groupby('Job_role')['min_salary(PA)'].plot(legend=True)
plt.title('Job_roles having minimum salary')
# Out:
# Text(0.5, 1.0, 'Job_roles having minimum salary')

# %% [markdown]
# * The data analyist and software developer are having the highest average salary packages in minimum salary
# * The Sales Manager and System Engineer having lowest avg salary packages in minimum salary

# %%
plt.figure(figsize=(10,5))
df2.groupby('Job_role')['max_salary(PA)'].plot(legend=True)
plt.title('Job_roles having maximum salary')
# Out:
# Text(0.5, 1.0, 'Job_roles having maximum salary')

# %% [markdown]
# * The data analyist and software developer are having the highest average salary packages in maximum salary
# * The Sales Manager and System Engineer having lowest avg salary packages in maximum salary

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = a, x = 'Rating', y = 'Job_role');
plt.title('Showing Job_role which are having Rating More than 4.5 ')
plt.show()

# %% [markdown]
# * Software Engineer and Data Analyst jobs having more Rating
# * System Engineer and Data Engineer jobs having less Rating

# %%
a = pd.DataFrame(df2[df2['Rating'] > 4.5])

# %%
a['Rating'],a['Job_role'].value_counts().plot(kind='barh')
plt.title('number of job_roles having more than 4.5 Rating')
# Out:
# Text(0.5, 1.0, 'number of job_roles having more than 4.5 Rating')

# %% [markdown]
# * Software Developer has more number of Jobs which are having more than 4.5 Rating
# * Data Analyst has less number of Jobs which are having more than 4.5 Rating

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = a, x = 'Rating', y = 'Company');
plt.title('Showing Companies which are having Rating More than 4.5 ')
plt.show()

# %% [markdown]
# * These are the top rated companies, the rating is more than 4.5

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = df2, x = 'Rating', y = 'min_salary(PA)');
plt.title('Rating vs Salary')
plt.show()

# %% [markdown]
# * The rating of the jobs as per the salary as we can know that 3.7 ,4.9 rated jobs are highest packages

# %% [markdown]
# # Multivariant Analysis

# %%
sns.pairplot(df2[["min_salary(PA)","Min_Experience(years)","Rating"]])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2[["Max_Experience(years)","min_salary(PA)","Rating"]].corr(),annot=True,cmap="Blues")
plt.title("Correlation",fontsize=15)
plt.show()

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <AxesSubplot:>
